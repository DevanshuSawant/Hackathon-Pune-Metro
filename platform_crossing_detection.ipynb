# %%
import ultralytics
import cv2
import pandas as pd
from ultralytics import YOLO
import numpy as np
from shapely.geometry import Point, Polygon
from PIL import Image, ImageDraw, ImageFont
import supervision as sv

segmentation_model = YOLO('models/platform-segmentation-model.pt')
pose_model = YOLO('models/yolov8x-pose.pt')
video_path = 'dataset/platform-crossing/3_jump.mp4'
image_path = 'frames/platform-crossing-3-jump/frame_149.jpg'

# %%
def is_point_inside_polygon(point, polygon):
    point = Point(point)
    polygon = Polygon(polygon)
    return polygon.contains(point)

def callback(image_slice: np.ndarray) -> sv.KeyPoints:
    result = pose_model(image_slice)[0]
    return sv.KeyPoints.from_ultralytics(result)
slicer = sv.InferenceSlicer(callback = callback)

def use_sahi(image):
    detections = slicer(image)
    points = []

    for detection in detections.xyxy:
        left_bottom_corner = (int(detection[0]), int(detection[3]))
        right_bottom_corner = (int(detection[2]), int(detection[3]))  
        # print(left_bottom_corner, right_bottom_corner)
        cv2.circle(image, left_bottom_corner, 5, (0, 255, 0), -1)
        cv2.circle(image, right_bottom_corner, 5, (0, 255, 0), -1)
        points.append(left_bottom_corner)
        points.append(right_bottom_corner)
    # cv2.imwrite('output.jpg', image)

    return points, image
 

def check_boundaries(image, warning_mask, danger_mask):
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 3
    color = (255, 0, 0)  # BGR color format
    thickness = 2
    
    leg_points, image = use_sahi(image)
    if len(leg_points) == 0:
        return image
    for point in leg_points:
        # cv2.circle(image, tuple(point.astype(np.int32)), 5, (0, 255, 0), -1)
        # is_inside_safe = is_point_inside_polygon(point, safe_mask)
        
        is_inside_warning = is_point_inside_polygon(point, warning_mask)
        is_inside_danger = is_point_inside_polygon(point, danger_mask)
        
        if is_inside_warning:
            cv2.putText(image, 'Warning', (50, 50), font, font_scale, color, thickness)
            print('Warning')
            # cv2.circle(image, tuple(point.astype(np.int32)), 5, (255, 255, 0), -1)
        elif is_inside_danger:
            cv2.putText(image, 'Danger', (50, 200), font, font_scale, color, thickness)
            print('Danger')
            # cv2.circle(image, tuple(point.astype(np.int32)), 5, (255, 0, 0), -1)
        # elif is_inside_safe:
        #     cv2.circle(image, tuple(point.astype(np.int32)), 5, (0, 255, 0), -1)
    return image

# %%
# Open the video file
video = cv2.VideoCapture(video_path)
fps = video.get(cv2.CAP_PROP_FPS)
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
# Read the first frame
ret, frame = video.read()

# Check if the frame was successfully read
if ret:
    # Display the first frame
    result = segmentation_model.predict(frame, save=True)[0]
else:
    print('Error reading the video file.')

# Release the video file
video.release()
# Out:
# 0: 384x640 1 safe_area, 1 train_area, 1 warning_area, 680.6ms
# Speed: 3.6ms preprocess, 680.6ms inference, 706.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\segment\predict15

# %%
classes = np.array(result.boxes.cls)
# safe_index = np.where(classes == 0)[0]
warning_index = np.where(classes == 2)[0]
danger_index = np.where(classes == 1)[0]

# safe_mask = result.masks.xy[safe_index[0]].astype(np.int32)
warning_mask = result.masks.xy[warning_index[0]].astype(np.int32)
danger_mask = result.masks.xy[danger_index[0]].astype(np.int32)
# scene = image.copy()
# for i in range(len(results[0].masks.xy)):
#     mask = results[0].masks.xy[0].astype(np.int32)
#     polygon = sv.PolygonZone(mask)
#     # scene = image.copy()
#     image = sv.draw_polygon(scene, polygon.polygon, sv.Color(r=255, g=255, b=0), 2)
    
# with sv.ImageSink(target_dir_path='output') as sink:
#     sink.save_image(image=scene, image_name='platform_segments.jpg')

# %%
detections = slicer(frame)
# Out:
# 0: 640x640 (no detections), 1323.0ms
# Speed: 5.9ms preprocess, 1323.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1219.8ms
# Speed: 4.5ms preprocess, 1219.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1219.8ms
# Speed: 5.5ms preprocess, 1219.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1275.7ms
# Speed: 5.0ms preprocess, 1275.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1250.0ms
# Speed: 5.5ms preprocess, 1250.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1257.1ms
# Speed: 5.5ms preprocess, 1257.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1286.7ms
# Speed: 6.5ms preprocess, 1286.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 553.1ms
# Speed: 3.0ms preprocess, 553.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 1268.7ms
# Speed: 4.0ms preprocess, 1268.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1289.8ms
# Speed: 3.0ms preprocess, 1289.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1238.4ms
# Speed: 5.5ms preprocess, 1238.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1216.9ms
# Speed: 5.5ms preprocess, 1216.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1207.7ms
# Speed: 5.0ms preprocess, 1207.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1218.2ms
# Speed: 5.5ms preprocess, 1218.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1247.5ms
# Speed: 5.5ms preprocess, 1247.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 541.7ms
# Speed: 1.0ms preprocess, 541.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 1225.8ms
# Speed: 5.0ms preprocess, 1225.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1263.8ms
# Speed: 4.0ms preprocess, 1263.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1351.6ms
# Speed: 5.5ms preprocess, 1351.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1225.3ms
# Speed: 4.0ms preprocess, 1225.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1321.1ms
# Speed: 4.5ms preprocess, 1321.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1244.8ms
# Speed: 6.0ms preprocess, 1244.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1232.3ms
# Speed: 5.0ms preprocess, 1232.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 542.4ms
# Speed: 2.5ms preprocess, 542.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 1218.6ms
# Speed: 3.5ms preprocess, 1218.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1239.6ms
# Speed: 3.0ms preprocess, 1239.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2048.9ms
# Speed: 4.0ms preprocess, 2048.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2656.6ms
# Speed: 17.0ms preprocess, 2656.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2777.9ms
# Speed: 5.6ms preprocess, 2777.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2787.1ms
# Speed: 10.1ms preprocess, 2787.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2069.5ms
# Speed: 5.6ms preprocess, 2069.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 644.2ms
# Speed: 2.5ms preprocess, 644.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 128x640 (no detections), 303.5ms
# Speed: 1.5ms preprocess, 303.5ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 300.2ms
# Speed: 0.0ms preprocess, 300.2ms inference, 1.5ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 288.8ms
# Speed: 1.0ms preprocess, 288.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 292.0ms
# Speed: 1.0ms preprocess, 292.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 314.6ms
# Speed: 1.0ms preprocess, 314.6ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 302.0ms
# Speed: 2.0ms preprocess, 302.0ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 371.9ms
# Speed: 0.0ms preprocess, 371.9ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 288x640 (no detections), 678.7ms
# Speed: 3.0ms preprocess, 678.7ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 detections = slicer(frame)
#
# File d:\GitHub\Hackathon-Pune-Metro\.venv\Lib\site-packages\supervision\detection\tools\inference_slicer.py:109, in InferenceSlicer.__call__(self, image)
#     105     futures = [
#     106         executor.submit(self._run_callback, image, offset) for offset in offsets
#     107     ]
#     108     for future in as_completed(futures):
# --> 109         detections_list.append(future.result())
#     111 return Detections.merge(detections_list=detections_list).with_nms(
#     112     threshold=self.iou_threshold
#     113 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File d:\GitHub\Hackathon-Pune-Metro\.venv\Lib\site-packages\supervision\detection\tools\inference_slicer.py:129, in InferenceSlicer._run_callback(self, image, offset)
#     127 image_slice = crop_image(image=image, xyxy=offset)
#     128 detections = self.callback(image_slice)
# --> 129 detections = move_detections(detections=detections, offset=offset[:2])
#     131 return detections
#
# File d:\GitHub\Hackathon-Pune-Metro\.venv\Lib\site-packages\supervision\detection\tools\inference_slicer.py:20, in move_detections(detections, offset)
#      11 def move_detections(detections: Detections, offset: np.array) -> Detections:
#      12     """
#      13     Args:
#      14         detections (sv.Detections): Detections object to be moved.
#    (...)
#      18         (sv.Detections) repositioned Detections object.
#      19     """
# ---> 20     detections.xyxy = move_boxes(xyxy=detections.xyxy, offset=offset)
#      21     return detections
#
# AttributeError: 'KeyPoints' object has no attribute 'xyxy'

# %%
vertex_annotator = sv.VertexAnnotator(color=sv.Color.GREEN, radius=10)
annotated_frame = vertex_annotator.annotate(
    scene=frame.copy(),
    key_points=key_points
)

# %%
image = check_boundaries(frame, warning_mask, danger_mask)
cv2.imwrite('output.jpg', image)
# Out:
# 0: 640x640 (no detections), 1305.6ms
# Speed: 5.0ms preprocess, 1305.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1257.5ms
# Speed: 7.2ms preprocess, 1257.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1277.2ms
# Speed: 3.5ms preprocess, 1277.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1288.8ms
# Speed: 5.0ms preprocess, 1288.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1266.6ms
# Speed: 6.0ms preprocess, 1266.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1264.5ms
# Speed: 4.0ms preprocess, 1264.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1240.0ms
# Speed: 4.0ms preprocess, 1240.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 566.3ms
# Speed: 1.5ms preprocess, 566.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 2921.7ms
# Speed: 6.0ms preprocess, 2921.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2737.2ms
# Speed: 6.4ms preprocess, 2737.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 3103.3ms
# Speed: 7.0ms preprocess, 3103.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2485.8ms
# Speed: 4.7ms preprocess, 2485.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2549.7ms
# Speed: 5.1ms preprocess, 2549.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2631.3ms
# Speed: 8.1ms preprocess, 2631.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2519.5ms
# Speed: 6.4ms preprocess, 2519.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 1176.2ms
# Speed: 2.8ms preprocess, 1176.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 2523.2ms
# Speed: 6.0ms preprocess, 2523.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2634.0ms
# Speed: 6.3ms preprocess, 2634.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2682.4ms
# Speed: 6.1ms preprocess, 2682.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2607.9ms
# Speed: 7.0ms preprocess, 2607.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2528.0ms
# Speed: 8.5ms preprocess, 2528.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 2547.8ms
# Speed: 5.1ms preprocess, 2547.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2392.3ms
# Speed: 7.0ms preprocess, 2392.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 1048.8ms
# Speed: 2.0ms preprocess, 1048.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 3451.7ms
# Speed: 4.1ms preprocess, 3451.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 3236.8ms
# Speed: 9.0ms preprocess, 3236.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 3011.9ms
# Speed: 7.0ms preprocess, 3011.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2581.9ms
# Speed: 6.0ms preprocess, 2581.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2499.2ms
# Speed: 4.0ms preprocess, 2499.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2571.3ms
# Speed: 8.6ms preprocess, 2571.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2594.0ms
# Speed: 4.1ms preprocess, 2594.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 1194.0ms
# Speed: 1.0ms preprocess, 1194.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 128x640 (no detections), 584.9ms
# Speed: 1.1ms preprocess, 584.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 542.2ms
# Speed: 2.0ms preprocess, 542.2ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 564.9ms
# Speed: 1.6ms preprocess, 564.9ms inference, 2.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 853.0ms
# Speed: 2.1ms preprocess, 853.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 553.6ms
# Speed: 1.6ms preprocess, 553.6ms inference, 0.9ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 552.2ms
# Speed: 1.0ms preprocess, 552.2ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 556.7ms
# Speed: 1.1ms preprocess, 556.7ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 288x640 (no detections), 1178.0ms
# Speed: 3.0ms preprocess, 1178.0ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 image = check_boundaries(frame, warning_mask, danger_mask)
#       2 cv2.imwrite('output.jpg', image)
#
# Cell In[4], line 34, in check_boundaries(image, warning_mask, danger_mask)
#      31 color = (255, 0, 0)  # BGR color format
#      32 thickness = 2
# ---> 34 leg_points, image = use_sahi(image)
#      35 if len(leg_points) == 0:
#      36     return image
#
# Cell In[4], line 12, in use_sahi(image)
#      11 def use_sahi(image):
# ---> 12     detections = slicer(image)
#      13     points = []
#      15     for detection in detections.xyxy:
#
# File d:\GitHub\Hackathon-Pune-Metro\.venv\Lib\site-packages\supervision\detection\tools\inference_slicer.py:109, in InferenceSlicer.__call__(self, image)
#     105     futures = [
#     106         executor.submit(self._run_callback, image, offset) for offset in offsets
#     107     ]
#     108     for future in as_completed(futures):
# --> 109         detections_list.append(future.result())
#     111 return Detections.merge(detections_list=detections_list).with_nms(
#     112     threshold=self.iou_threshold
#     113 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File d:\GitHub\Hackathon-Pune-Metro\.venv\Lib\site-packages\supervision\detection\tools\inference_slicer.py:129, in InferenceSlicer._run_callback(self, image, offset)
#     127 image_slice = crop_image(image=image, xyxy=offset)
#     128 detections = self.callback(image_slice)
# --> 129 detections = move_detections(detections=detections, offset=offset[:2])
#     131 return detections
#
# File d:\GitHub\Hackathon-Pune-Metro\.venv\Lib\site-packages\supervision\detection\tools\inference_slicer.py:20, in move_detections(detections, offset)
#      11 def move_detections(detections: Detections, offset: np.array) -> Detections:
#      12     """
#      13     Args:
#      14         detections (sv.Detections): Detections object to be moved.
#    (...)
#      18         (sv.Detections) repositioned Detections object.
#      19     """
# ---> 20     detections.xyxy = move_boxes(xyxy=detections.xyxy, offset=offset)
#      21     return detections
#
# AttributeError: 'KeyPoints' object has no attribute 'xyxy'

# %%
# import cv2
# from tqdm import tqdm

# # Path to the video file
# # video_path = 'dataset/platform-crossing/5_jump.avi'
# output_path = 'video_with_new_image.avi'
# results = pose_model.predict(video_path, stream=True, vid_stride=10)  # predict on an image

# # Open the video file
# frame_count = 0
# # Get the video properties



# # Create a tqdm progress bar
# progress_bar = tqdm(total=total_frames, desc='Processing Frames')
# fourcc = cv2.VideoWriter_fourcc(*'XVID')
# output_video = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# # Read the new image

# # Iterate over the frames in the video
# for pose_result in results:
#     frame = check_boundaries(pose_result, warning_mask, danger_mask)

#     # Write the modified frame to the output video
#     output_video.write(frame)
    
#     frame_count += 1
#     progress_bar.update(1)
# # Release the video file and the output video
# output_video.release()

# %%
import cv2

# Open the video file

cap = cv2.VideoCapture(video_path)

# Create a VideoWriter object to save the modified video
output_path = 'path_to_save_modified_video.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# Loop through each frame of the video
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    image = check_boundaries(frame, warning_mask, danger_mask)
    out.write(image)

# Release the video capture and writer objects
cap.release()
out.release()
# Out:
# 0: 640x640 (no detections), 1947.8ms
# Speed: 12.5ms preprocess, 1947.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1884.0ms
# Speed: 5.0ms preprocess, 1884.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1740.0ms
# Speed: 6.5ms preprocess, 1740.0ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1917.6ms
# Speed: 6.6ms preprocess, 1917.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1913.2ms
# Speed: 6.0ms preprocess, 1913.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1936.8ms
# Speed: 7.5ms preprocess, 1936.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1845.0ms
# Speed: 5.5ms preprocess, 1845.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 852.1ms
# Speed: 3.0ms preprocess, 852.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 1742.6ms
# Speed: 5.5ms preprocess, 1742.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1827.4ms
# Speed: 8.3ms preprocess, 1827.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1719.2ms
# Speed: 7.0ms preprocess, 1719.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1718.6ms
# Speed: 5.1ms preprocess, 1718.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1696.7ms
# Speed: 6.5ms preprocess, 1696.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1673.2ms
# Speed: 6.5ms preprocess, 1673.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1752.9ms
# Speed: 8.5ms preprocess, 1752.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 804.2ms
# Speed: 3.0ms preprocess, 804.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 1727.5ms
# Speed: 5.7ms preprocess, 1727.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1820.7ms
# Speed: 5.5ms preprocess, 1820.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1870.6ms
# Speed: 7.5ms preprocess, 1870.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1856.2ms
# Speed: 8.5ms preprocess, 1856.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1825.6ms
# Speed: 4.5ms preprocess, 1825.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1838.5ms
# Speed: 6.3ms preprocess, 1838.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1863.8ms
# Speed: 6.5ms preprocess, 1863.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 834.3ms
# Speed: 2.5ms preprocess, 834.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 1820.7ms
# Speed: 7.0ms preprocess, 1820.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1842.2ms
# Speed: 6.8ms preprocess, 1842.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1775.6ms
# Speed: 4.0ms preprocess, 1775.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1804.8ms
# Speed: 7.5ms preprocess, 1804.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1867.6ms
# Speed: 6.0ms preprocess, 1867.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1813.1ms
# Speed: 6.5ms preprocess, 1813.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1795.1ms
# Speed: 8.6ms preprocess, 1795.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 967.1ms
# Speed: 2.5ms preprocess, 967.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 128x640 (no detections), 459.7ms
# Speed: 4.0ms preprocess, 459.7ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 459.4ms
# Speed: 2.2ms preprocess, 459.4ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 470.4ms
# Speed: 1.5ms preprocess, 470.4ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 470.6ms
# Speed: 1.0ms preprocess, 470.6ms inference, 1.5ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 423.2ms
# Speed: 2.0ms preprocess, 423.2ms inference, 1.5ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 501.0ms
# Speed: 1.0ms preprocess, 501.0ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 457.9ms
# Speed: 1.0ms preprocess, 457.9ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 288x640 (no detections), 913.6ms
# Speed: 2.4ms preprocess, 913.6ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x640 (no detections), 1968.5ms
# Speed: 15.2ms preprocess, 1968.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1781.2ms
# Speed: 8.1ms preprocess, 1781.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1915.1ms
# Speed: 4.5ms preprocess, 1915.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1878.7ms
# Speed: 6.0ms preprocess, 1878.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1823.1ms
# Speed: 6.5ms preprocess, 1823.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1848.1ms
# Speed: 7.0ms preprocess, 1848.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1866.9ms
# Speed: 8.1ms preprocess, 1866.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 902.9ms
# Speed: 1.0ms preprocess, 902.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 
4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1745.3ms
# Speed: 6.0ms preprocess, 1745.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1706.4ms
# Speed: 6.0ms preprocess, 1706.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1673.2ms
# Speed: 6.0ms preprocess, 1673.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1753.6ms
# Speed: 7.0ms preprocess, 1753.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1709.7ms
# Speed: 7.0ms preprocess, 1709.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1811.6ms
# Speed: 7.1ms preprocess, 1811.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 722.7ms
# Speed: 1.0ms preprocess, 722.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 1336.2ms
# Speed: 4.0ms preprocess, 1336.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1368.4ms
# Speed: 5.0ms preprocess, 1368.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1297.9ms
# Speed: 5.0ms preprocess, 1297.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1281.0ms
# Speed: 4.0ms preprocess, 1281.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1273.1ms
# Speed: 4.0ms preprocess, 1273.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1251.1ms
# Speed: 5.0ms preprocess, 1251.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1286.4ms
# Speed: 3.0ms preprocess, 1286.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x288 (no detections), 616.4ms
# Speed: 2.7ms preprocess, 616.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 128x640 (no detections), 293.8ms
# Speed: 2.0ms preprocess, 293.8ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 293.9ms
# Speed: 1.0ms preprocess, 293.9ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 300.8ms
# Speed: 1.0ms preprocess, 300.8ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 287.6ms
# Speed: 1.0ms preprocess, 287.6ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 298.5ms
# Speed: 1.0ms preprocess, 298.5ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 302.6ms
# Speed: 1.0ms preprocess, 302.6ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 128x640 (no detections), 291.5ms
# Speed: 1.0ms preprocess, 291.5ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 288x640 (no detections), 596.8ms
# Speed: 2.0ms preprocess, 596.8ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x640 (no detections), 1306.5ms
# Speed: 5.0ms preprocess, 1306.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1257.9ms
# Speed: 5.0ms preprocess, 1257.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1285.3ms
# Speed: 5.0ms preprocess, 1285.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1269.2ms
# Speed: 3.0ms preprocess, 1269.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1265.4ms
# Speed: 3.0ms preprocess, 1265.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1327.8ms
# Speed: 5.0ms preprocess, 1327.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1614.9ms
# Speed: 6.0ms preprocess, 1614.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 835.9ms
# Speed: 2.0ms preprocess, 835.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 1764.9ms
# Speed: 8.5ms preprocess, 1764.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2176.8ms
# Speed: 7.0ms preprocess, 2176.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2088.4ms
# Speed: 8.0ms preprocess, 2088.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2023.5ms
# Speed: 7.9ms preprocess, 2023.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1946.3ms
# Speed: 9.1ms preprocess, 1946.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1870.6ms
# Speed: 6.0ms preprocess, 1870.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 2003.4ms
# Speed: 7.1ms preprocess, 2003.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 873.4ms
# Speed: 3.0ms preprocess, 873.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 5786.4ms
# Speed: 6.3ms preprocess, 5786.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1450.1ms
# Speed: 5.0ms preprocess, 1450.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1379.8ms
# Speed: 5.0ms preprocess, 1379.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1443.3ms
# Speed: 7.0ms preprocess, 1443.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1527.5ms
# Speed: 6.0ms preprocess, 1527.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1979.1ms
# Speed: 6.0ms preprocess, 1979.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1942.7ms
# Speed: 7.0ms preprocess, 1942.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x256 (no detections), 892.8ms
# Speed: 2.7ms preprocess, 892.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 640x640 (no detections), 1891.2ms
# Speed: 8.0ms preprocess, 1891.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
# bounding_box_annotator = sv.BoundingBoxAnnotator()
# annotated_frame = bounding_box_annotator.annotate(
#     scene=image.copy(),
#     detections=detections
# )

# with sv.ImageSink(target_dir_path='output') as sink:
#     sink.save_image(image=annotated_frame, image_name='platform_segments.jpg')
